# %% [markdown]
# # directed graph of learning objectives.

# %%
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout
import matplotlib.pyplot as plt

# %%
# here we define a list of nodes
labels_dsmcer = {
    # stat stuff
    0: 'compute basic statistics',
    1: '''measure probabaility
and cumulative density''',
    2: 'represent distributions in python',
    3: 'recognize common distros',
    4: '''differentiate samples,
empirical, and analytical distros''',
    5: 'impliment bootstrapping',
    6: 'run hypothesis tests',
    7: 'measure distro overlap',
    8: 'conduct data splitting',
    9: 'interpret distros',
    10: 'estimate global statistics',
    11: 'compare distributions',
    12: 'draw conclusions from data',
    13: 'evaluate a traoning and testing split',
    
    # ML basic stuff
    14: """recognize components of a
model, params, hyps, and arch""",
    15: 'differentiate b/w sup and unsup',
    16: 'compute error, acc, and loss',
    17: 'measure distance b/w examples',
    18: 'produce machine readable feats',
    19: 'impliment data normalization',
    20: '''differentiate discrete vs
cont RVs''',
    21: 'describe regr vs classif',
    22: 'create, train, and score SML model',
    23: 'understand mechanism of KNN',
    
    # ML deeper
    24: '''describe data leakage in the
context of the ML task in question''',
    25: 'impliment encoding',
    26: 'compute or derive continuous features',
    27: '''intuit the math behind the
fitting of a linear model''',
    28: '''understand how a classification
model can be made from a cont output''',
    29: 'describe model bias and variance',
    30: 'consider model bias and variance tradeoff',
    31: 'recognize overfitting',
    32: 'describe multiple linear models',
    33: 'conduct and justify parameter regularization',
    34: '''recognize and consider from number
of common classical ML architectures''',
    35: 'recognize the components of a neuron',
    36: 'understand numerical gradient optimization',
    37: 'understand a NN',
    38: 'conduct dimensionality reduction',
    39: '''compute correlations and other
measures of feature quality''',
    40: 'produce an optimized set of features',
    41: 'conduct model validation',
    42: 'impliment hyperparameter optimization',
    43: '''optimize a supervise ML model with
a desired task in mind and faithfully
report its capability''',
    44: 'posit clusters and classes in unlabeled data',
    45: 'create a model to suggest new data',
    46: '''optimize an unsupervise ML model with
a desired task in mind and faithfully
report its capability''',
    47: '''tackle and communicate a reproducable
tool, solution, or method using data science
applied to physical sciences''',
    # visualize
    48: "create visual representations of data",
    49: '''communicate plots of
distributions and results''',
}
nodes_dsmcer = list(labels_dsmcer.keys())

# %%
labels_seds = {
    # basic
    100: "Can use shell to run commands with arguments",
    101: """able to navigate and interact with
system through terminal""",
    102: "understand the dif b/w SE and progr",
    103: """able to open and run python
in a noebook or terminal""",
    104: """differentiate b/w builtin operators
and reserved words""",
    105: """define and use variables, functions,
data types""",
    106: """can create and manipulate
builtin data structures""",
    107: """operate on sets if numbers
using numpy and pandas""",
#     108: """load and manipulate tabular
# data using pandas""",
    109: "compute aggregate quantities",
    110: "identify and value the process of VC",
    111: """can conduct basic git/hub:
clone, add, commit, push, pull, merge""",
    112: """install and import 3rd
party modules of code""",
    113: """develop a functionality using conditions,
loops, and functions""",
    114: "Intepret and debug error messages",
    115: """use assert or custom exceptions 
to check code execution""",
    116: "create a custom module of code",
    
    # CI and reproducability
    117: "write unit tests for custom functions",
    118: "describe functionalities with doc strings",
    119: """use a testing suite to detect
and test a custom package""",
    120: """differentiate between syntax and style""",
    121: "develop code in a consistant readable style",
    122: """use tools to test code style as if
it were code bugs""",
    123: "write use cases and components spec",
    124: "conduct design of software",
    125: "use branches, and forks to collaborate on code",
    126: "recognize and resolve merge conflicts",
    127: "issue pull requests to collaborators",
    128: """create and control a code environment for
a specific task""",
    129: """setup workflows for CI using
written tests and pull requests""",
 
}
nodes_seds = list(labels_seds.keys())

# %%
edges = [
    # stats
    (0, 9),
    (1, 9),
    (2, 9),
    (3, 9),
    (4, 10),
    (9, 10),
    (5, 10),
    (9, 6),
    (9, 7),
    (6, 11),
    (7, 11),
    (11, 12),
    (10, 12),
    (11, 13),
    (8, 13),
    
    # basic ML
    (14, 22),
    (15, 22),
    (16, 22),
    (18, 13),
    (19, 22),
    (20, 21),
    (21, 22),
    (17, 23),
    (23, 22),
    (13, 22),
    
    # ML deeper
    (24, 8),
    (25, 18),
    (26, 18),
    (20,18),
    (14, 27),
    (27, 28),
    (21,28),
    (14, 31),
    (29, 30),
    (22, 30),
    (31, 29),
    (27, 32),
    (31, 33),
    (32, 33),
    (33, 30),
    (33, 34),
    (32, 34),
    (30, 34),
    (32, 35),
    (16, 36),
    (35, 37),
    (36, 37),
    (30, 37),
    (28, 37),
    (37, 34),
    (17, 38),
    (38, 40),
    (12, 39),
    (39, 40),
    (18, 17),
    (30, 41),
    (41, 42),
    (42, 43),
    (40, 43),
    (34, 43),
    (15, 38),
    (15, 44),
    (15, 45),
    (22, 44),
    (38, 46),
    (44, 46),
    (45, 46),
    (43, 47),
    (46, 47),
    (12, 47),

    (48, 49),
    (48, 12),
    (49, 47),
    
    # seds
    (100, 101),
    (100, 103),
    (103, 104),
    (103, 105),
    (104, 106),
    (105, 106),
    (105, 112),
    (106, 107),
    (112, 107),
    (107, 109),
    (102, 110),
    (110, 111),
    (101, 111),
    (106, 113),
    (112, 113),
    (113, 114),
    (113, 115),
    (113, 116),
    (118, 116),
    (114, 117),
    (115, 117),
    (117, 119),
    (116, 119),
    (120, 121),
    (121, 122),
    (120, 123),
    (123, 124),
    (102, 120),
    (111, 125),
    (125, 126),
    (127, 125),
    (100, 128),
    (112, 128),
    (128, 129),
    (119, 129),
    (126, 129),
    
    # # coupling
    (107, 48),
    (107, 2),
    (109, 0),
    (109, 1),
    (113, 5),
    (107, 16),
    (107, 26),
    (129, 47),
    (124, 47),
    (122, 47)
]

# %%
nodes = nodes_dsmcer + nodes_seds

# %%
node_colors = ['tab:blue']*len(nodes_dsmcer) + ['tab:green']*len(nodes_seds)

# %%
labels_seds.update(labels_dsmcer)
labels = labels_seds

# %%
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
pos = graphviz_layout(G, prog="dot")
# pos = dict(zip(pos.keys(), [(v[1], v[0]) for v in pos.values()]))

# %%
fig, ax = plt.subplots(figsize=(40,40));
nx.draw_networkx(G, pos=pos,with_labels=False, arrows = True,
    node_shape = 's', node_color = node_colors)
text = nx.draw_networkx_labels(G,pos, labels=labels)
for _,t in text.items():
    t.set_rotation(15)

# %% [markdown]
# 4. Grouped and distilled nodes:

# %% [markdown]
# Key: S = SEDS, D = DSMCER
#
# Penultimate LO:
# 1. (S,D) create and communicate a reproducable tool, solution, or method using data science techniques applied to the physical sciences as a team
#     - Requires: 2, 13, 14
#
# 2. (S) conduct a design of an open source, importable piece of python software
#     - Requires: 3,4,5
# 3. (S) apply a uniform and legible coding style
# 4. (S) plan the use cases and components of a piece of software
#    - Requires: 12
# 5. (S) leverage continuous integration in writing software
#     - Requires: 6, 7
# 6. (S) apply version control to collaborate and track code
#     - Requires: 8, 9
# 7. (S) write documented and unit tested functionalities
#     - Requires: 10, 11
# 8. (S) Explain the relationship between git, gitthub, and version control
# 9. (S) Maintain a code environment
#     - Requires: 12
# 10. (S) Apply the concepts of flow control: variables, functions, loops, conditionals
# 11. (S) Leverage data types and structures of python: numbers, strings, lists, dictionaries, numpy and pandas
# 12. (S) Explain the relationship between: libraries, modules, importing
#
# 13. (D) Optimize a machine learning model and faithfully report its capability
#     - Requires: 18, 19
# 14. (D) Communicate conclusions and results drawn from data
#     - Requires: 15, 16
# 15. (D) Produce concise visual representations
#     - Requires: 11
# 16. (D) Analyze observations, distributions, and samples of data
#     - Requires: 17
# 17. (D) Interpret probabilities to determine statistical significance of measurements
#     - Requires: 11
# 18. (D) develop a rigorous test using available data based on the purpose of the model
#     - Requires: 23
# 19. (D) Conduct hyperparameter optimization
#     - Requires: 20, 21, 22
# 20. (D) Prioritize cost-capability trade off in terms of time and carbon
# 21. (D) choose a model validation scheme
#     - Requires: 23, 10
# 22. (D) Compare and choose from the gallery of possible supervised and unsupervised model architectures
#     - Requires: 24, 25, 26
# 23. (D) Prioritize bias-variance tradeoff
#     - Requires: 16, 28, 30, 31
# 24. (D) Recognize popular architectures for unsupervised, supervised, and semisupervised tasks
#     - Requires: 27, 28, 29
# 25. (D) Engineer and preprocess features
#     - Requires: 23
# 26. (D) leverage regularization techniques including ensembles and paramater suppression
#     - Requires: 23
# 27. (D) desribe the components and the training process of neural networks
# 28. (D) distinguish unsupervised, supervised, and semisupervised problems such as clustering, diensionality reduction, prediction, generation, sample suggestion
# 29. (D) Distinguish continuous, discrete, multitask outputs
# 30. (D) distinguish parameters and hyperparameters
# 31. (D) Use the python DS stack to load data and models to train, make inferences, and score
#     - Requires: 12

# %%
labels_ultimate = {1: 'create and communicate a reproducable tool, solution, or method using data science techniques applied to the physical sciences as a team'}

# %%
labels_seds = {
    2: 'conduct a design of an open source, importable piece of python software',
    3: 'apply a uniform and legible coding style',
    4: 'plan the use cases and components of a piece of software',
    5: 'leverage continuous integration in writing software',
    6: 'apply version control to collaborate and track code',
    7: 'write documented and unit tested functionalities',
    8: 'Explain the relationship between git, gitthub, and version control',
    9: 'Maintain a code environment',
    10: 'Apply the concepts of flow control: variables, functions, loops, conditionals',
    11: 'Leverage data types and structures of python: numbers, strings, lists, dictionaries, numpy and pandas',
    12: 'Explain the relationship between: libraries, modules, importing',
}
labels_dsmcer = {
    13: 'Optimize a machine learning model and faithfully report its capability',
    14: 'Communicate conclusions and results drawn from data',
    15: 'Produce concise visual representations',
    16: 'Analyze observations, probabilities, distributions, and samples of data to determine statistical significance of measurements',
    # 17: 'Interpret probabilities to determine statistical significance of measurements',
    18: 'develop a rigorous test using available data based on the purpose of the model',
    19: 'Conduct hyperparameter optimization',
    20: 'Prioritize cost-capability trade off in terms of time and carbon',
    21: 'choose a model validation scheme',
    22: 'Compare and choose from the gallery of possible supervised and unsupervised model architectures',
    23: 'Prioritize bias-variance tradeoff',
    24: 'Recognize popular architectures for unsupervised, supervised, and semisupervised tasks',
    25: 'Engineer and preprocess features',
    26: 'leverage regularization techniques including ensembles and paramater suppression',
    27: 'desribe the components and the training process of neural networks',
    28: 'distinguish unsupervised, supervised, and semisupervised problems such as clustering, diensionality reduction, prediction, generation, sample suggestion',
    29: 'Distinguish continuous, discrete, multitask outputs',
    30: 'distinguish parameters and hyperparameters',
    31: 'Use the python DS stack to load data and models to train, make inferences, and score'
}

# %%
nodes_ultimate = list(labels_ultimate.keys())
nodes_seds = list(labels_seds.keys())
nodes_dsmcer = list(labels_dsmcer.keys())
labels = {}
labels.update(labels_dsmcer)
labels.update(labels_seds)
labels.update(labels_ultimate)

# %%
# make the strings better looking
new_labels = {}
for k, v in labels.items():
    split = [v[i:i+28] for i in range(0, len(v), 28)]
    to_join = []
    for part in split[:-1]:
        if not part[-1] in [' ', ',']:
            part += '-'
        to_join.append(part)
    to_join.append(split[-1])
    new_labels[k] = '\n'.join(to_join)
labels = new_labels

# %%
nodes = nodes_ultimate  + nodes_dsmcer+nodes_seds
node_colors = ['purple'] + ['tab:blue']*len(nodes_dsmcer) + ['tab:green']*len(nodes_seds)

# %%
edges = [
    (1, 2),
    (1, 13),
    (1, 14),
    (2, 3),
    (2, 4),
    (2, 5),
    (4, 12),
    (5, 6),
    (5, 7),
    (6, 8),
    (6, 9),
    (7, 10),
    (7, 11),
    (9, 12),
    
    (13, 18),
    (13, 19),
    (14, 15),
    (14, 16),
    (15, 11),
    # (16, 17),
    # (17, 11),
    (16, 11),
    (18, 23),
    (19, 20),
    (19, 21),
    (19, 22),
    (21, 10),
    (21, 23),
    (22, 24),
    (22, 25),
    (22, 26),
    (23, 16),
    (23, 28),
    (23, 30),
    (23, 31),
    (24, 27),
    (24, 28),
    (24, 29),
    (25, 23),
    (26, 23),
    (31, 12)
]

# %%
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
pos = graphviz_layout(G, prog="dot")
# pos = dict(zip(pos.keys(), [(v[1], v[0]) for v in pos.values()]))

# %%
fig, ax = plt.subplots(figsize=(35,20));
nx.draw_networkx(G, pos=pos, with_labels=False, arrows = True,
    node_shape = 's', node_color = node_colors)
text = nx.draw_networkx_labels(G,pos, labels=labels)
